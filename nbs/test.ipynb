# %%
import os
import pandas as pd

# %%
df = pd.read_parquet(os.path.abspath("../data/coinbase_stream_23-04-09_17-25-32.096785.parquet"))
df.head()
# Out:
#                                 ts product_id  ask_price1  ask_price2
# 0 2023-04-09 21:25:12.029332+00:00    BTC-USD    28169.58    28169.59  \
# 1 2023-04-09 21:25:12.032738+00:00    BTC-USD    28169.58    28169.59
# 2 2023-04-09 21:25:12.033047+00:00    BTC-USD    28169.58    28169.59
# 3 2023-04-09 21:25:12.033495+00:00    BTC-USD    28169.58    28169.59
# 4 2023-04-09 21:25:12.039772+00:00    BTC-USD    28169.58    28169.59
#
#    ask_price3  ask_price4  ask_price5  ask_price6  ask_price7  ask_price8
# 0    28169.63    28169.64    28170.06    28170.07    28170.25    28170.26  \
# 1    28169.63    28169.64    28170.06    28170.07    28170.25    28170.26
# 2    28169.63    28169.64    28170.06    28170.07    28170.25    28170.26
# 3    28169.63    28169.64    28170.06    28170.07    28170.25    28170.26
# 4    28169.63    28169.64    28170.06    28170.07    28170.25    28170.26
#
#    ...  bid_volume11  bid_volume12  bid_volume13  bid_volume14  bid_volume15
# ...

# %%
df.dtypes
# Out:
# ts              datetime64[ns, UTC]
# product_id                   object
# ask_price1                  float64
# ask_price2                  float64
# ask_price3                  float64
#                        ...
# bid_volume16                float64
# bid_volume17                float64
# bid_volume18                float64
# bid_volume19                float64
# bid_volume20                float64
# Length: 82, dtype: object
